# %% [markdown]
# # Assignment 2: Linear Regression, Data Cleaning, and Feature Engineering

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Load data into pandas dataframe

# %%
df = pd.read_csv("KC_housing_data.csv")
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# ## Basic data analysis

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Checking for missing data

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# ### Removing rows of unsold houses
# There are a relatively small amount of houses with no price listed so there is less of a data hit with taking them out of the dataset. Including these rows could severely throw off the statistical data of house pricing.

# %%
(df['price'] == 0).sum()
# Out:
# np.int64(49)

# %%
cleaned_df = df[df['price']>0]
cleaned_df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.551000e+03  4551.000000  4551.000000   4551.000000  4.551000e+03
# mean   5.579059e+05     3.394639     2.155021   2132.372226  1.483528e+04
# std    5.639299e+05     0.904595     0.776351    955.949708  3.596408e+04
# min    7.800000e+03     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.262643e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.650000e+05     3.000000     2.250000   1970.000000  7.680000e+03
# 75%    6.575000e+05     4.000000     2.500000   2610.000000  1.097800e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4551.000000  4551.000000  4551.000000  4551.000000  4551.000000
# mean      1.512195     0.006592     0.234674     3.449352  1822.221710
# std       0.538531     0.080932     0.765373     0.675160   854.452888
# ...

# %%
renovated_df = cleaned_df[cleaned_df["yr_renovated"]>0]

# %%
renovated_df.loc[:, "renovation_age"] = 2025 - renovated_df.loc[:,"yr_renovated"]

# %%
renovated_df.head()
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   2014-05-02 00:00:00  313000.0       3.0       1.50         1340      7912
# 4   2014-05-02 00:00:00  550000.0       4.0       2.50         1940     10500
# 5   2014-05-02 00:00:00  490000.0       2.0       1.00          880      6380
# 9   2014-05-02 00:00:00  640000.0       4.0       2.00         1520      6200
# 10  2014-05-02 00:00:00  463000.0       3.0       1.75         1710      7320
#
#     floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0      1.5           0     0          3        1340              0      1955
# 4      1.0           0     0          4        1140            800      1976
# 5      1.0           0     0          3         880              0      1938
# 9      1.5           0     0          3        1520              0      1945
# 10     1.0           0     0          3        1710              0      1948
#
# ...

# %%
y = renovated_df['price']
x = renovated_df[['renovation_age']]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x
# Out:
#       renovation_age
# 0                 20
# 4                 33
# 5                 31
# 9                 15
# 10                31
# ...              ...
# 4587              31
# 4589              53
# 4593             102
# 4595              46
# 4596              16
#
# [1845 rows x 1 columns]

# %%
# scaler = StandardScaler()
# x_train_scaled = scaler.fit_transform(x_train)
# x_test_scaled = scaler.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.00024458368728730306

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 101302160088.49387

# %%
plt.scatter(x,y,color="red")
plt.plot(x_test,y_pred,color='green')
plt.show()
